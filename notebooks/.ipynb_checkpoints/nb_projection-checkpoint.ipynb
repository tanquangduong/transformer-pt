# %%
import sys
sys.path.append('../')
import torch
from transformer.layers import Projection

# %%
# Define the dimensions and vocabulary size
d_model = 512
vocab_size = 10000

# Create an instance of the Projection class
projection = Projection(d_model, vocab_size)

# Create a random tensor to represent a batch of sequences
x = torch.rand(10, 20, d_model)  # batch_size=10, seq_len=20, d_model=512

# Pass the tensor through the projection
output = projection(x)

print(output.shape)  # Should print: torch.Size([10, 20, 10000])
# Out:
# torch.Size([10, 20, 10000])

# %%
output
# Out:
# tensor([[[ 0.0496,  0.3571, -0.1907,  ...,  0.3131,  0.3966, -0.4808],
#          [-0.1396,  0.1023, -0.1602,  ...,  0.4924,  0.2474, -0.1528],
#          [ 0.0912,  0.2351, -0.1880,  ...,  0.4197,  0.4695, -0.3650],
#          ...,
#          [ 0.0737,  0.4360, -0.1026,  ...,  0.3751,  0.6284, -0.1418],
#          [-0.0017,  0.2202, -0.0413,  ...,  0.4863,  0.3547, -0.1993],
#          [ 0.0481,  0.0450, -0.0015,  ...,  0.3376,  0.4654, -0.5468]],
#
#         [[-0.1897,  0.1712,  0.0743,  ...,  0.2417,  0.5980, -0.1558],
#          [ 0.0374,  0.3194, -0.1717,  ...,  0.4476,  0.4829, -0.4935],
#          [ 0.1137,  0.2671, -0.1163,  ...,  0.2659,  0.4034, -0.1441],
#          ...,
#          [ 0.1861,  0.3264, -0.3173,  ...,  0.1434,  0.2475,  0.0087],
#          [ 0.0303,  0.5541, -0.0288,  ...,  0.1695,  0.4491, -0.3544],
#          [ 0.2156,  0.2713,  0.2082,  ...,  0.1986,  0.4763, -0.3523]],
#
#         [[-0.0398,  0.0456, -0.2504,  ...,  0.5650,  0.5615,  0.0673],
#          [-0.1692,  0.0638, -0.0702,  ...,  0.1460,  0.5831, -0.1181],
#          [-0.1537, -0.2881, -0.1977,  ...,  0.1634,  0.2638, -0.3516],
#          ...,
#          [-0.0189,  0.3374, -0.2804,  ..., -0.0534,  0.5070, -0.2808],
#          [ 0.2047,  0.5664, -0.3890,  ...,  0.2812,  0.3769, -0.3729],
#          [ 0.1006,  0.1377, -0.3006,  ...,  0.1823,  0.4291, -0.1842]],
#
#         ...,
#
#         [[-0.0362,  0.0619, -0.3676,  ...,  0.0105,  0.2391, -0.1024],
#          [ 0.0819,  0.0774, -0.1752,  ...,  0.3365,  0.2886, -0.0770],
#          [ 0.0445,  0.1609, -0.0693,  ...,  0.1698,  0.3889, -0.2653],
#          ...,
#          [ 0.2398,  0.2593, -0.0213,  ...,  0.1419,  0.2451, -0.1015],
#          [-0.0352,  0.3275, -0.1423,  ...,  0.3845,  0.4600, -0.2906],
#          [ 0.0291,  0.1734, -0.3192,  ...,  0.3254,  0.5445, -0.2174]],
#
#         [[ 0.1685,  0.3315, -0.2949,  ...,  0.3528,  0.3064, -0.3653],
#          [ 0.0062,  0.3886, -0.1892,  ...,  0.2099,  0.2004, -0.0961],
#          [ 0.1372,  0.3038, -0.1140,  ...,  0.5022,  0.4456, -0.5375],
#          ...,
#          [ 0.0743, -0.1587, -0.1432,  ...,  0.3904,  0.5776, -0.1944],
#          [ 0.0027,  0.1095, -0.1478,  ...,  0.3014,  0.5266, -0.6771],
#          [-0.0242,  0.2415, -0.2207,  ...,  0.0049,  0.2709,  0.1090]],
#
#         [[ 0.0130,  0.1675, -0.0255,  ...,  0.1483,  0.5004, -0.4748],
#          [ 0.1864,  0.2046, -0.3050,  ...,  0.2188,  0.3499, -0.3370],
#          [-0.0303,  0.3534, -0.4296,  ...,  0.1541,  0.3739, -0.3549],
#          ...,
#          [-0.1895,  0.4773,  0.0730,  ..., -0.0649,  0.7124,  0.0909],
#          [-0.1103,  0.1775, -0.0232,  ...,  0.3299,  0.1606, -0.2280],
#          [ 0.1005,  0.3416, -0.3560,  ...,  0.3677,  0.2710, -0.2108]]],
#        grad_fn=<ViewBackward0>)
